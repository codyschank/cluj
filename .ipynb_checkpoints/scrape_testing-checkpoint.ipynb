# %%
import time
import re
import pandas as pd

from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from sklearn.preprocessing import StandardScaler

from secrets import *

# %%
email = AUTH["email"]
password = AUTH["password"]

# %% [markdown]
# ## LOGIN

# %%
# https://stackoverflow.com/questions/33326459/logging-into-espn-using-selenium

# %%
driver = webdriver.Chrome()

# %%
driver.get("http://games.espn.go.com/ffl/signin")

# %%
w = WebDriverWait(driver,1000).until(EC.presence_of_all_elements_located((By.XPATH,"(//iframe)")))

# %%
driver.switch_to_frame("disneyid-iframe")
time.sleep(2)
# Out:
# /Users/codyschank/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: use driver.switch_to.frame instead
#   """Entry point for launching an IPython kernel.

# %%
driver.find_element_by_css_selector('input[type=email]').send_keys(email)

# %%
driver.find_element_by_css_selector('input[type=password]').send_keys("answers5")

# %%
driver.find_element_by_xpath("//button").click()

# %% [markdown]
# ## STATS

# %%
leagueID = "84057"
url = "http://fantasy.espn.com/basketball/players/add?leagueId="+leagueID+"&view=stats"
url
# Out:
# 'http://fantasy.espn.com/basketball/players/add?leagueId=84057&view=stats'

# %%
driver.get(url)

# %%
# show all players
driver.find_element_by_xpath("//*[@id='filterStatus']/option[1]").click()

# %%
# show totals
driver.find_element_by_xpath("//*[@id='espn-analytics']/div/div[5]/div[2]/div[2]/div/div/div[1]/div/div[3]/label[1]/div").click()

# %%
xpath = '//*[@id="espn-analytics"]/div/div[5]/div[2]/div[2]/div/div/div[2]/section/table/tbody'
table = driver.find_element_by_xpath(xpath)

# %%
cells = table.text.split('\n')

# %%
nba_teams = ['Hou','Mil','No','GS','LAL','OKC','Phi','Min','Por','Ind','Tor','Den','Bos','SA','Wsh','Utah','Cle','Det',
            'Cha','Phx','Dal','Mem','LAC','Mia','Atl','NY','Orl','Chi','Sac','Bkn']

# %%
# clean out unnecessary/ complicating data
cells = [i for i in cells if i not in ['O','DTD']]
cells = [i for i in cells if i not in nba_teams]
cells = [i for i in cells if '@' not in i]
cells = [i for i in cells if ':' not in i]
players = cells[6:156]
stats = cells[170:]

# %%
columns = ['player','position','fantasy_team','fgm/fga','fg%','ftm/fta','ft%','3pm','reb','ast','stl','blk','pts','pr5','own','change']
statsTable = pd.DataFrame()

# %%
j = 0
k = 0
for i in range(50):
    player = players[j:j+3]
    j = j+3
    player_stats = stats[k:k+13]
    k = k+13
    values = player+player_stats
    row = dict(zip(columns, values))
    statsTable = statsTable.append(row, ignore_index=True)

# %%
# this is another way to do it, with less cleanging post scraprin, but hits that page many more times, and thus flags the account
'''for i in range(1,51):
    xpath = '//*[@id="espn-analytics"]/div/div[5]/div[2]/div[2]/div/div/div[2]/section/table/tbody/tr/td[1]/table/tbody/tr[' + str(i) + ']/td[1]'
    playername = driver.find_element_by_xpath(xpath)
    playername = playername.text.split('\n')
    playername = [j for j in playername if j not in ['O','DTD']]
    xpath = '//*[@id="espn-analytics"]/div/div[5]/div[2]/div[2]/div/div/div[2]/section/table/tbody/tr/td[1]/table/tbody/tr[' + str(i) + ']/td[2]'
    fantasyteam = driver.find_element_by_xpath(xpath)
    fantasyteam = fantasyteam.text.split('\n')
    xpath = '//*[@id="espn-analytics"]/div/div[5]/div[2]/div[2]/div/div/div[2]/section/table/tbody/tr/td[2]/div/div/div[2]/table/tbody/tr/td/table/tbody/tr[' + str(i) + ']'
    stats = driver.find_element_by_xpath(xpath)
    stats = stats.text.split('\n')
    values = playername+fantasyteam+stats
    row = dict(zip(columns, values))
    statsTable = statsTable.append(row, ignore_index=True)
''' and None

# %%
statsTable.head()
# Out:
#    3pm  ast  blk change fantasy_team   fg%   fgm/fga   ft%  ftm/fta   own  \
# 0  261  647   47    0.0         Wood  .445  653/1466  .855  660/772  99.9
# 1   51  468  125    0.0         DEKK  .541  861/1591  .772  524/679  99.9
# 2   50  168  212    0.0         DOIS  .519  807/1555  .813  522/642  99.9
# 3  178  390  120    0.0         Ingl  .519  693/1335  .886  412/465  99.9
# 4  147  450   53    0.0          BEB  .553  759/1373  .747  387/518  99.9
#
#                   player position pr5   pts  reb  stl
# 0           James Harden   SG, PG  --  2227  491  125
# 1  Giannis Antetokounmpo   PF, SF  --  2297  842  117
# 2          Anthony Davis    PF, C  --  2186  883  131
# 3           Kevin Durant   SF, PF  --  1976  555   68
# 4           LeBron James   SF, PF  --  2052  593   98

# %%
for i in range(2,6):
    next_page = "//*[@id='espn-analytics']/div/div[5]/div[2]/div[2]/div/div/div[2]/div/div/ul/li["+str(i)+"]"
    driver.find_element_by_xpath(next_page).click()
    time.sleep(4)
    xpath = '//*[@id="espn-analytics"]/div/div[5]/div[2]/div[2]/div/div/div[2]/section/table/tbody'
    table = driver.find_element_by_xpath(xpath)
    cells = table.text.split('\n')
    cells = [i for i in cells if i not in ['O','DTD']]
    cells = [i for i in cells if i not in nba_teams]
    cells = [i for i in cells if '@' not in i]
    cells = [i for i in cells if ':' not in i]
    players = cells[6:156]
    stats = cells[170:]
    j = 0
    k = 0
    for i in range(50):
        player = players[j:j+3]
        j = j+3
        player_stats = stats[k:k+13]
        k = k+13
        values = player+player_stats
        row = dict(zip(columns, values))
        statsTable = statsTable.append(row, ignore_index=True)

# %%
statsTable.loc[statsTable.player == 'Anthony Davis']
# Out:
#   3pm  ast  blk change fantasy_team   fg%   fgm/fga   ft%  ftm/fta   own  \
# 2  50  168  212    0.0         DOIS  .519  807/1555  .813  522/642  99.9
#
#           player position pr5   pts  reb  stl
# 2  Anthony Davis    PF, C  --  2186  883  131

# %%
statsTable.shape
# Out:
# (250, 16)

# %% [markdown]
# ## ANALYZE

# %%
statsTable['fta'] = statsTable['ftm/fta'].str.split('/',expand=True)[1]
statsTable['fga'] = statsTable['fgm/fga'].str.split('/',expand=True)[1]
statsTable = statsTable.drop(columns = ['pr5','own','change','ftm/fta','fgm/fga'])

# %%
statsTable = statsTable.replace("--","0")

# %%
statsTable['ast'] = pd.to_numeric(statsTable['ast']) 
statsTable['blk'] = pd.to_numeric(statsTable['blk']) 
statsTable['reb'] = pd.to_numeric(statsTable['reb']) 
statsTable['pts'] = pd.to_numeric(statsTable['pts']) 
statsTable['stl'] = pd.to_numeric(statsTable['stl'])
statsTable['3pm'] = pd.to_numeric(statsTable['3pm'])
statsTable['ft%'] = pd.to_numeric(statsTable['ft%'])
statsTable['fg%'] = pd.to_numeric(statsTable['fg%'])
statsTable['fta'] = pd.to_numeric(statsTable['fta'])
statsTable['fga'] = pd.to_numeric(statsTable['fga'])

# %%
scaler = StandardScaler()

# %%
statsTable[['ast', 'blk','reb','pts','stl','3pm','ft%','fg%','fta','fga']] = scaler.fit_transform(statsTable[['ast', 'blk','reb','pts','stl','3pm','ft%','fg%','fta','fga']])

# %%
statsTable.head()
# Out:
#         3pm       ast       blk fantasy_team       fg%       ft%  \
# 0  2.746146  3.104418  0.078457         Wood -0.172719  0.727102
# 1 -0.582731  1.829418  2.185778         DEKK  0.980343  0.110989
# 2 -0.598583 -0.307453  4.536252         DOIS  0.716099  0.415334
# 3  1.430447  1.273831  2.050694         Ingl  0.716099  0.957217
# 4  0.939041  1.701206  0.240559          BEB  1.124476 -0.074587
#
#                   player position       pts       reb       stl       fta  \
# 0           James Harden   SG, PG  2.903950  0.568773  1.842478  4.273773
# 1  Giannis Antetokounmpo   PF, SF  3.066670  2.332997  1.580595  3.562314
# 2          Anthony Davis    PF, C  2.808643  2.539074  2.038891  3.279260
# 3           Kevin Durant   SF, PF  2.320484  0.890455 -0.023439  1.925193
# 4           LeBron James   SF, PF  2.497151  1.081454  0.958623  2.330648
#
#         fga
# 0  2.195047
# 1  2.591411
# 2  2.477258
# 3  1.779657
# 4  1.900152

# %%
statsTable['fga_adj'] = statsTable['fga'] + abs(statsTable['fga'].min())
statsTable['fta_adj'] = statsTable['fta'] + abs(statsTable['fta'].min())

# %%
statsTable['fg%_adj'] = statsTable['fg%'] * statsTable['fga_adj']
statsTable['ft%_adj'] = statsTable['ft%'] * statsTable['fta_adj']

# %%
statsTable[['fg%_adj','ft%_adj']] = scaler.fit_transform(statsTable[['fg%_adj','ft%_adj']])

# %%
statsTable = statsTable.drop(columns = ['fga_adj','fta_adj','fg%','ft%','fta','fga'])

# %%
statsTable['cumulative'] = statsTable['ft%_adj'] + statsTable['fg%_adj'] + statsTable['ast'] + statsTable['blk'] + statsTable['pts'] + statsTable['reb'] + statsTable['stl'] + statsTable['3pm']

# %%
statsTable = statsTable.sort_values('cumulative',ascending=False)

# %%
statsTable.head()
# Out:
#         3pm       ast       blk fantasy_team                 player position  \
# 2 -0.598583 -0.307453  4.536252         DOIS          Anthony Davis    PF, C
# 1 -0.582731  1.829418  2.185778         DEKK  Giannis Antetokounmpo   PF, SF
# 0  2.746146  3.104418  0.078457         Wood           James Harden   SG, PG
# 7  0.400080 -0.043906  1.915609         WILL     Karl-Anthony Towns        C
# 9  3.649699  1.872155 -0.786085          gov          Stephen Curry       PG
#
#         pts       reb       stl   fg%_adj   ft%_adj  cumulative
# 2  2.808643  2.539074  2.038891  2.258000  1.360170   14.634993
# 1  3.066670  2.332997  1.580595  3.229826  0.235687   13.878239
# 0  2.903950  0.568773  1.842478 -0.718831  3.092478   13.617869
# 7  2.520397  3.252805 -0.088909  2.991641  1.686900   12.634618
# 9  2.313510 -0.074590  2.104361  0.795113  2.426145   12.300308

# %% [markdown]
# ## My team

# %%
my_players = ['Kelly Olynyk','Patrick Beverley','Shai Gilgeous-Alexander','Bobby Portis','Buddy Hield','Jaylen Brown','Damian Lillard','Andre Drummond','LaMarcus Aldridge','Kevin Durant', 'Jeremy Lamb','Dennis Schroder','TJ Warren']

# %%
my_team = statsTable.loc[statsTable.player.isin(my_players)]

# %%
my_team
# Out:
#           3pm       ast       blk fantasy_team                   player  \
# 3    1.430447  1.273831  2.050694         Ingl             Kevin Durant
# 10   2.381555  2.064474 -0.569949         Ingl           Damian Lillard
# 21  -1.391173  0.013078  2.212795         Ingl           Andre Drummond
# 19  -0.757101 -0.186364  1.726490         Ingl        LaMarcus Aldridge
# 69   1.747483 -0.407174  0.672830         Ingl             Jaylen Brown
# 120  1.652372 -0.321699 -0.542932         Ingl              Buddy Hield
# 79  -0.788804 -0.905777 -0.056627         Ingl                TJ Warren
# 151  0.178155 -0.164995 -0.164695         Ingl             Kelly Olynyk
# 117  0.174985 -0.093766 -0.380831         Ingl              Jeremy Lamb
# 92  -0.233992  1.202602 -1.002220         Ingl          Dennis Schroder
# 165  0.225711  0.924809 -0.623983         Ingl         Patrick Beverley
# 141 -0.186436 -0.663598 -0.596966         Ingl             Bobby Portis
# 172 -1.074137  1.110005 -0.407848         Ingl  Shai Gilgeous-Alexander
#
#     position       pts       reb       stl   fg%_adj   ft%_adj  cumulative
# 3     SF, PF  2.320484  0.890455 -0.023439  1.914866  2.409279   12.266617
# 10        PG  2.652897 -0.079616  0.271180 -0.948107  3.600038    9.372471
# 21         C  0.914122  4.454085  1.646066  3.666905 -3.795195    7.720683
# 19     PF, C  1.927632  1.624292 -0.481734  1.765636  1.197946    6.816798
# 69        SG  0.658419  0.267197  2.300774  0.247833 -0.565500    4.921862
# 120       SG  0.414340 -0.190194  0.336651 -0.675851  0.231892    0.904578
# 79        SF  0.897850 -0.104748  0.271180  0.907374 -0.139269    0.081178
# 151        C -0.283030  0.211908 -0.285322  0.427181 -0.200484   -0.281281
# 117   SG, SF  0.065655 -0.371140 -0.514469 -0.196686  0.629666   -0.686586
# 92        PG  0.326006 -0.944136 -0.088909 -0.663176  0.633183   -0.770641
# 165       PG -0.917636 -0.436482  0.533063 -0.588336 -0.295998   -1.178853
# 141       PF -0.085442  0.629089 -0.809088  0.075551 -0.162440   -1.799331
# 172       PG -1.105926 -0.743085  0.336651 -0.475129 -0.315395   -2.674864

# %%
my_team[['ast','blk','pts','reb','stl','3pm','ft%_adj','fg%_adj']].sum(axis=0)
# Out:
# ast        3.845427
# blk        2.316756
# pts        7.785371
# reb        5.207625
# stl        3.492604
# 3pm        3.359065
# ft%_adj    3.227722
# fg%_adj    5.458062
# dtype: float64

# %%
opp_players = ['Stephen Curry','DeMar DeRozan','Gordon Hayward','Carmelo Anthony','Steven Adams','Donovan Mitchell','Kevin Knox','James Johnson','Reggie Jackson','Malcolm Brogdon','Kyle O\'Quinn','DeMarre Carroll','Mario Hezonja']

# %%
opp_team = statsTable.loc[statsTable.player.isin(opp_players)]

# %%
opp_team
# Kyle O'Quinn not showing up...not scraped, too bad of a player?
# Out:
#           3pm       ast       blk fantasy_team            player position  \
# 9    3.649699  1.872155 -0.786085          gov     Stephen Curry       PG
# 18   1.953556  1.074390 -0.353814          gov  Donovan Mitchell       SG
# 16   0.463488  1.174111 -0.759068          gov     DeMar DeRozan   SG, SF
# 34   0.685413  0.205396 -0.569949          gov    Gordon Hayward   SF, SG
# 102 -0.313251  0.582910  1.051067          gov     James Johnson       PF
# 72  -1.391173 -0.898654  0.888965          gov      Steven Adams        C
# 76   1.145115 -0.093766 -0.569949          gov   Carmelo Anthony   PF, SF
# 155  0.460317 -0.357313 -0.596966          gov     Mario Hezonja       SF
# 138 -0.107177  0.632770 -0.786085          gov   Malcolm Brogdon   SG, PG
# 88   0.130600  1.451904 -1.002220          gov    Reggie Jackson       PG
# 84  -0.979026 -0.428542  0.375643          gov        Kevin Knox       SF
# 160  0.812227 -0.592369 -0.434865          gov   DeMarre Carroll   SF, PF
#
#           pts       reb       stl   fg%_adj   ft%_adj  cumulative
# 9    2.313510 -0.074590  2.104361  0.795113  2.426145   12.300308
# 18   2.183335 -0.351035  1.777008 -0.577101  1.049928    6.756266
# 16   2.450660 -0.089669  0.631269 -0.103256  1.915275    5.682810
# 34   1.034999 -0.124853  0.205709 -0.232711  1.129141    2.333144
# 102 -0.157503  0.025936  0.467592  0.522428 -0.569033    1.610146
# 72  -0.050573  1.352873  0.533063  2.499254 -2.311560    0.622195
# 76   0.477103 -0.029353 -0.514469 -0.199430  0.388819    0.604070
# 155 -0.027328 -0.029353  0.860417 -0.641571  0.393459    0.061661
# 138 -0.403907 -0.803400  0.467592 -0.087566  0.406809   -0.680964
# 88   0.474779 -0.853663 -0.710882 -1.068523  0.822786   -0.755220
# 84   0.460831  0.201855  0.336651 -0.823622 -0.146616   -1.002826
# 160 -0.183074  0.242065  0.074768 -1.140002 -0.207770   -1.429019

# %%
opp_team[['ast','blk','pts','reb','stl','3pm','ft%_adj','fg%_adj']].sum(axis=0)
# Out:
# ast        4.622992
# blk       -3.543325
# pts        8.572831
# reb       -0.533187
# stl        6.233079
# 3pm        6.509788
# ft%_adj    5.297381
# fg%_adj   -1.056988
# dtype: float64

# %%
# rather than use PR, use stat averages, and num games played during the matchup.
