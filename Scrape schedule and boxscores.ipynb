# %%
import datetime
import time
import pytz
import pandas as pd

from itertools import chain
from datetime import timedelta, date, datetime, timezone
from basketball_reference_web_scraper import client

from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database

from secrets import *

# %%
dbname = 'cluj'
engine = create_engine('postgres://%s:%s@localhost/%s'%('docker','docker',dbname))

if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))
# Out:
# True

# %%
#https://stackoverflow.com/questions/1060279/iterating-through-a-range-of-dates-in-python

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
schedule = client.season_schedule(season_end_year=2020)

# %%
start = schedule[0]['start_time']
end = datetime.now(pytz.timezone('US/Central')) - timedelta(days=1)
start, end
# Out:
# (datetime.datetime(2018, 10, 17, 0, 0, tzinfo=<UTC>),
#  datetime.datetime(2020, 1, 11, 21, 39, 13, 831959, tzinfo=<DstTzInfo 'US/Central' CST-1 day, 18:00:00 STD>))

# %%
schedule_df = pd.DataFrame(schedule)
schedule_df['away_team'] = schedule_df.away_team.apply(lambda x: x.name)
schedule_df['home_team'] = schedule_df.home_team.apply(lambda x: x.name)
schedule_df['start_time'] = schedule_df.start_time.apply(lambda x: x.tz_localize(None))
schedule_df['start_date'] = schedule_df.start_time.apply(lambda x: x.date())
schedule_df['season_end_year'] = 2020
schedule_df.head()
# Out:
#               away_team  away_team_score             home_team  \
# 0  NEW_ORLEANS_PELICANS            122.0       TORONTO_RAPTORS
# 1    LOS_ANGELES_LAKERS            102.0  LOS_ANGELES_CLIPPERS
# 2         CHICAGO_BULLS            125.0     CHARLOTTE_HORNETS
# 3       DETROIT_PISTONS            119.0        INDIANA_PACERS
# 4   CLEVELAND_CAVALIERS             85.0         ORLANDO_MAGIC
#
#    home_team_score          start_time  start_date  season_end_year
# 0            130.0 2019-10-23 00:00:00  2019-10-23             2020
# 1            112.0 2019-10-23 02:30:00  2019-10-23             2020
# 2            126.0 2019-10-23 23:00:00  2019-10-23             2020
# 3            110.0 2019-10-23 23:00:00  2019-10-23             2020
# 4             94.0 2019-10-23 23:00:00  2019-10-23             2020

# %%
schedule_df.to_sql('nba_schedule', con=engine, if_exists='replace', index=False)

# %%
for year in range(2001, 2020):
    print(year)
    schedule = client.season_schedule(season_end_year=year)
    schedule_df = pd.DataFrame(schedule)
    schedule_df['away_team'] = schedule_df.away_team.apply(lambda x: x.name)
    schedule_df['home_team'] = schedule_df.home_team.apply(lambda x: x.name)
    schedule_df['start_time'] = schedule_df.start_time.apply(lambda x: x.tz_localize(None))
    schedule_df['start_date'] = schedule_df.start_time.apply(lambda x: x.date())
    schedule_df['season_end_year'] = year
    schedule_df.to_sql('nba_schedule', con=engine, if_exists='append', index=False)
# Out:
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019

# %%
#boxscores_list = []
#for day in daterange(start, end):
#    print(day)
#    boxscores = client.player_box_scores(day=day.day, month=day.month, year=day.year)
#    for item in boxscores:
#        item.update( {"date":datetime.strftime(day.date(), format = '%Y-%m-%d')})
#    boxscores_list.append(boxscores)
#    time.sleep(2)
# Out:
# 2018-10-17 00:00:00+00:00
# 2018-10-18 00:00:00+00:00
# 2018-10-19 00:00:00+00:00
# 2019-06-19 00:00:00+00:00
# 2019-06-20 00:00:00+00:00
# 2019-06-21 00:00:00+00:00
# 2019-06-22 00:00:00+00:00
# 2019-06-23 00:00:00+00:00
# 2019-06-24 00:00:00+00:00
# 2019-06-25 00:00:00+00:00
# 2019-06-26 00:00:00+00:00
# 2019-06-27 00:00:00+00:00
# 2019-06-28 00:00:00+00:00
# 2019-06-29 00:00:00+00:00
# 2019-06-30 00:00:00+00:00
# 2019-07-01 00:00:00+00:00
# 2019-07-02 00:00:00+00:00
# 2019-07-03 00:00:00+00:00
# 2019-07-04 00:00:00+00:00
# 2019-07-05 00:00:00+00:00
# 2019-07-06 00:00:00+00:00
# 2019-07-07 00:00:00+00:00
# 2019-07-08 00:00:00+00:00
# 2019-07-09 00:00:00+00:00
# 2019-07-10 00:00:00+00:00
# 2019-07-11 00:00:00+00:00
# 2019-07-12 00:00:00+00:00
# 2019-07-13 00:00:00+00:00
# 2019-07-14 00:00:00+00:00
# 2019-07-15 00:00:00+00:00
# 2019-07-16 00:00:00+00:00
# 2019-07-17 00:00:00+00:00
# 2019-07-18 00:00:00+00:00
# 2019-07-19 00:00:00+00:00
# 2019-07-20 00:00:00+00:00
# 2019-07-21 00:00:00+00:00
# 2019-07-22 00:00:00+00:00
# 2019-07-23 00:00:00+00:00
# 2019-07-24 00:00:00+00:00
# 2019-07-25 00:00:00+00:00
# 2019-07-26 00:00:00+00:00
# 2019-07-27 00:00:00+00:00
# 2019-07-28 00:00:00+00:00
# 2019-07-29 00:00:00+00:00
# 2019-07-30 00:00:00+00:00
# 2019-07-31 00:00:00+00:00
# 2019-08-01 00:00:00+00:00
# 2019-08-02 00:00:00+00:00
# 2019-08-03 00:00:00+00:00
# 2019-08-04 00:00:00+00:00
# 2019-08-05 00:00:00+00:00
# 2019-08-06 00:00:00+00:00
# 2019-08-07 00:00:00+00:00
# 2019-08-08 00:00:00+00:00
# 2019-08-09 00:00:00+00:00
# 2019-08-10 00:00:00+00:00
# 2019-08-11 00:00:00+00:00
# 2019-08-12 00:00:00+00:00
# 2019-08-13 00:00:00+00:00
# 2019-08-14 00:00:00+00:00
# 2019-08-15 00:00:00+00:00
# 2019-08-16 00:00:00+00:00
# 2019-08-17 00:00:00+00:00
# 2019-08-18 00:00:00+00:00
# 2019-08-19 00:00:00+00:00
# 2019-08-20 00:00:00+00:00
# 2019-08-21 00:00:00+00:00
# 2019-08-22 00:00:00+00:00
# 2019-08-23 00:00:00+00:00
# 2019-08-24 00:00:00+00:00
# 2019-08-25 00:00:00+00:00
# 2019-08-26 00:00:00+00:00
# 2019-08-27 00:00:00+00:00
# 2019-08-28 00:00:00+00:00
# 2019-08-29 00:00:00+00:00
# 2019-08-30 00:00:00+00:00
# 2019-08-31 00:00:00+00:00
# 2019-09-01 00:00:00+00:00
# 2019-09-02 00:00:00+00:00
# 2019-09-03 00:00:00+00:00
# 2019-09-04 00:00:00+00:00
# 2019-09-05 00:00:00+00:00
# 2019-09-06 00:00:00+00:00
# 2019-09-07 00:00:00+00:00
# 2019-09-08 00:00:00+00:00
# 2019-09-09 00:00:00+00:00
# 2019-09-10 00:00:00+00:00
# 2019-09-11 00:00:00+00:00
# 2019-09-12 00:00:00+00:00
# 2019-09-13 00:00:00+00:00
# 2019-09-14 00:00:00+00:00
# 2019-09-15 00:00:00+00:00
# 2019-09-16 00:00:00+00:00
# 2019-09-17 00:00:00+00:00
# 2019-09-18 00:00:00+00:00
# 2019-09-19 00:00:00+00:00
# 2019-09-20 00:00:00+00:00
# 2019-09-21 00:00:00+00:00
# 2019-09-22 00:00:00+00:00
# 2019-09-23 00:00:00+00:00
# 2019-09-24 00:00:00+00:00
# 2019-09-25 00:00:00+00:00
# 2019-09-26 00:00:00+00:00
# 2019-09-27 00:00:00+00:00
# 2019-09-28 00:00:00+00:00
# 2019-09-29 00:00:00+00:00
# 2019-09-30 00:00:00+00:00
# 2019-10-01 00:00:00+00:00
# 2019-10-02 00:00:00+00:00
# 2019-10-03 00:00:00+00:00
# 2019-10-04 00:00:00+00:00
# 2019-10-05 00:00:00+00:00
# 2019-10-06 00:00:00+00:00
# 2019-10-07 00:00:00+00:00
# 2019-10-08 00:00:00+00:00
# 2019-10-09 00:00:00+00:00
# 2019-10-10 00:00:00+00:00
# 2019-10-11 00:00:00+00:00
# 2019-10-12 00:00:00+00:00
# 2019-10-13 00:00:00+00:00
# 2019-10-14 00:00:00+00:00
# 2019-10-15 00:00:00+00:00
# 2019-10-16 00:00:00+00:00
# 2019-10-17 00:00:00+00:00
# 2019-10-18 00:00:00+00:00
# 2019-10-19 00:00:00+00:00
# 2019-10-20 00:00:00+00:00
# 2019-10-21 00:00:00+00:00
# 2019-10-22 00:00:00+00:00
# 2019-10-23 00:00:00+00:00
# 2019-10-24 00:00:00+00:00
# 2019-10-25 00:00:00+00:00
# 2019-10-26 00:00:00+00:00
# 2019-10-27 00:00:00+00:00
# 2019-10-28 00:00:00+00:00
# 2019-10-29 00:00:00+00:00
# 2019-10-30 00:00:00+00:00
# 2019-10-31 00:00:00+00:00
# 2019-11-01 00:00:00+00:00
# 2019-11-02 00:00:00+00:00
# 2019-11-03 00:00:00+00:00
# 2019-11-04 00:00:00+00:00
# 2019-11-05 00:00:00+00:00
# 2019-11-06 00:00:00+00:00
# 2019-11-07 00:00:00+00:00
# 2019-11-08 00:00:00+00:00
# 2019-11-09 00:00:00+00:00
# 2019-11-10 00:00:00+00:00
# 2019-11-11 00:00:00+00:00
# 2019-11-12 00:00:00+00:00
# 2019-11-13 00:00:00+00:00
# 2019-11-14 00:00:00+00:00
# 2019-11-15 00:00:00+00:00
# 2019-11-16 00:00:00+00:00
# 2019-11-17 00:00:00+00:00
# 2019-11-18 00:00:00+00:00
# 2019-11-19 00:00:00+00:00
# 2019-11-20 00:00:00+00:00
# 2019-11-21 00:00:00+00:00
# 2019-11-22 00:00:00+00:00
# 2019-11-23 00:00:00+00:00
# 2019-11-24 00:00:00+00:00
# 2019-11-25 00:00:00+00:00
# 2019-11-26 00:00:00+00:00
# 2019-11-27 00:00:00+00:00
# 2019-11-28 00:00:00+00:00
# 2019-11-29 00:00:00+00:00
# 2019-11-30 00:00:00+00:00
# 2019-12-01 00:00:00+00:00
# 2019-12-02 00:00:00+00:00
# 2019-12-03 00:00:00+00:00
# 2019-12-04 00:00:00+00:00
# 2019-12-05 00:00:00+00:00
# 2019-12-06 00:00:00+00:00
# 2019-12-07 00:00:00+00:00
# 2019-12-08 00:00:00+00:00
# 2019-12-09 00:00:00+00:00
# 2019-12-10 00:00:00+00:00
# 2019-12-11 00:00:00+00:00
# 2019-12-12 00:00:00+00:00
# 2019-12-13 00:00:00+00:00
# 2019-12-14 00:00:00+00:00
# 2019-12-15 00:00:00+00:00
# 2019-12-16 00:00:00+00:00
# 2019-12-17 00:00:00+00:00
# 2019-12-18 00:00:00+00:00
# 2019-12-19 00:00:00+00:00
# 2019-12-20 00:00:00+00:00
# 2019-12-21 00:00:00+00:00
# 2019-12-22 00:00:00+00:00
# 2019-12-23 00:00:00+00:00
# 2019-12-24 00:00:00+00:00
# 2019-12-25 00:00:00+00:00
# 2019-12-26 00:00:00+00:00
# 2019-12-27 00:00:00+00:00
# 2019-12-28 00:00:00+00:00
# 2019-12-29 00:00:00+00:00
# 2019-12-30 00:00:00+00:00
# 2019-12-31 00:00:00+00:00
# 2020-01-01 00:00:00+00:00
# 2020-01-02 00:00:00+00:00
# 2020-01-03 00:00:00+00:00
# 2020-01-04 00:00:00+00:00
# 2020-01-05 00:00:00+00:00
# 2020-01-06 00:00:00+00:00
# 2020-01-07 00:00:00+00:00
# 2020-01-08 00:00:00+00:00
# 2020-01-09 00:00:00+00:00
# 2020-01-10 00:00:00+00:00
# 2020-01-11 00:00:00+00:00

# %%
date = datetime.now() - timedelta(days=1)
print(date)
boxscores = client.player_box_scores(day=date.day, month=date.month, year=date.year)
# Out:
# 2020-01-11 21:35:14.469029

# %%
#boxscores_df = pd.DataFrame(list(chain.from_iterable(boxscores_list)))
boxscores_df = pd.DataFrame(boxscores)
boxscores_df['rebounds'] = boxscores_df.offensive_rebounds + boxscores_df.defensive_rebounds
boxscores_df.rename(columns={'attempted_field_goals':'fga', 'attempted_free_throws':'fta',
                            'made_three_point_field_goals':'threes', 'made_field_goals':'fgm',
                            'made_free_throws':'ftm'}, inplace=True)
boxscores_df['twos'] = boxscores_df.fgm - boxscores_df.threes
boxscores_df['points'] = (boxscores_df.threes * 3) + (boxscores_df.twos * 2) + (boxscores_df.ftm * 1)
boxscores_df.drop(columns=['attempted_three_point_field_goals','defensive_rebounds','offensive_rebounds',
                          'game_score','slug','turnovers','outcome','twos','personal_fouls','location'], inplace=True)
boxscores_df['opponent'] = boxscores_df.opponent.apply(lambda x: x.name)
boxscores_df['team'] = boxscores_df.team.apply(lambda x: x.name)
boxscores_df.columns.values
# Out:
# array(['assists', 'fga', 'fta', 'blocks', 'date', 'fgm', 'ftm', 'threes',
#        'name', 'opponent', 'seconds_played', 'steals', 'team', 'rebounds',
#        'points'], dtype=object)

# %%
boxscores_df.shape
# Out:
# (40204, 15)

# %%
boxscores_df.to_sql('boxscores', con=engine, if_exists='append', index=False)

# %%
boxscores_df.loc[boxscores_df.name.str.contains("Satorans")]
# Out:
#        assists  fga  fta  blocks  fgm  ftm  threes              name  \
# 181          3    5    0       1    1    0       0  Tomáš Satoranský
# 349          2    7    5       1    2    5       0  Tomáš Satoranský
# 602          4    7    0       0    3    0       2  Tomáš Satoranský
# 994          5    5    0       0    1    0       0  Tomáš Satoranský
# 1224         8    5    2       0    2    2       2  Tomáš Satoranský
# 1550         6    6    2       0    2    2       1  Tomáš Satoranský
# 1801         9    6    0       0    4    0       1  Tomáš Satoranský
# 2066         6    5    0       0    3    0       1  Tomáš Satoranský
# 2157         8   13    4       0   10    3       4  Tomáš Satoranský
# 2731         4   11    3       0    4    2       0  Tomáš Satoranský
# 3196         2    3    0       0    2    0       1  Tomáš Satoranský
# 3428         5    8    0       0    4    0       2  Tomáš Satoranský
# 3775         2    8    0       0    2    0       1  Tomáš Satoranský
# 4139         1    6    0       0    2    0       1  Tomáš Satoranský
# 4287         7   11    0       0    6    0       3  Tomáš Satoranský
# 4638         5    5    2       0    2    2       0  Tomáš Satoranský
# 4764         8    8    0       1    4    0       2  Tomáš Satoranský
# 5169         5   12    0       0    5    0       1  Tomáš Satoranský
# 5341         7   12    3       0    7    2       3  Tomáš Satoranský
# 5667         8    8    2       0    4    2       2  Tomáš Satoranský
# 6206         5    9    8       0    3    8       0  Tomáš Satoranský
# 6482         8   10    9       0    3    7       0  Tomáš Satoranský
# 6871         5    7    0       0    3    0       0  Tomáš Satoranský
# 7177         2    8    2       0    2    2       0  Tomáš Satoranský
# 7266        11    8    0       0    4    0       2  Tomáš Satoranský
# 7642         4    5    0       0    3    0       1  Tomáš Satoranský
# 7968         3    8    4       0    2    3       0  Tomáš Satoranský
# 8094         5    7    4       1    2    3       0  Tomáš Satoranský
# 8338         6    9    2       1    4    2       1  Tomáš Satoranský
# 8600         6   11    1       0    7    1       2  Tomáš Satoranský
# 9093         5   11    2       0    6    2       2  Tomáš Satoranský
# 9383         3   12    0       0    8    0       4  Tomáš Satoranský
# 9996         6    8    1       0    5    0       1  Tomáš Satoranský
# 10424        7   11    0       0    4    0       2  Tomáš Satoranský
# 10809        4    7    2       0    3    2       0  Tomáš Satoranský
# 11125        5   11    3       0    4    3       1  Tomáš Satoranský
# 11417       14   12    4       0    3    4       1  Tomáš Satoranský
# 11861        1    6    2       0    2    1       1  Tomáš Satoranský
# 12061        3   11    2       1    5    2       1  Tomáš Satoranský
#
#                      opponent  seconds_played  steals           team  \
# 181         CHARLOTTE_HORNETS            1462       0  CHICAGO_BULLS
# 349         MEMPHIS_GRIZZLIES            1317       4  CHICAGO_BULLS
# 602           TORONTO_RAPTORS            1578       1  CHICAGO_BULLS
# 994           NEW_YORK_KNICKS            1608       1  CHICAGO_BULLS
# 1224      CLEVELAND_CAVALIERS            1635       0  CHICAGO_BULLS
# 1550          DETROIT_PISTONS            1587       0  CHICAGO_BULLS
# 1801           INDIANA_PACERS            1619       2  CHICAGO_BULLS
# 2066       LOS_ANGELES_LAKERS            1594       1  CHICAGO_BULLS
# 2157            ATLANTA_HAWKS            1800       1  CHICAGO_BULLS
# 2731          HOUSTON_ROCKETS            1438       3  CHICAGO_BULLS
# 3196          NEW_YORK_KNICKS            1401       0  CHICAGO_BULLS
# 3428          MILWAUKEE_BUCKS            1645       3  CHICAGO_BULLS
# 3775            BROOKLYN_NETS            1712       3  CHICAGO_BULLS
# 4139          MILWAUKEE_BUCKS            1073       0  CHICAGO_BULLS
# 4287          DETROIT_PISTONS            1571       2  CHICAGO_BULLS
# 4638               MIAMI_HEAT            1260       2  CHICAGO_BULLS
# 4764        CHARLOTTE_HORNETS            1653       3  CHICAGO_BULLS
# 5169   PORTLAND_TRAIL_BLAZERS            1629       0  CHICAGO_BULLS
# 5341    GOLDEN_STATE_WARRIORS            2102       2  CHICAGO_BULLS
# 5667   PORTLAND_TRAIL_BLAZERS            1790       1  CHICAGO_BULLS
# 6206         SACRAMENTO_KINGS            2015       1  CHICAGO_BULLS
# 6482        MEMPHIS_GRIZZLIES            1994       3  CHICAGO_BULLS
# 6871    GOLDEN_STATE_WARRIORS            1939       2  CHICAGO_BULLS
# 7177               MIAMI_HEAT            1363       0  CHICAGO_BULLS
# 7266          TORONTO_RAPTORS            2279       2  CHICAGO_BULLS
# 7642            ATLANTA_HAWKS            1438       1  CHICAGO_BULLS
# 7968        CHARLOTTE_HORNETS            1544       0  CHICAGO_BULLS
# 8094     LOS_ANGELES_CLIPPERS            1674       2  CHICAGO_BULLS
# 8338    OKLAHOMA_CITY_THUNDER            1980       3  CHICAGO_BULLS
# 8600       WASHINGTON_WIZARDS            2065       1  CHICAGO_BULLS
# 9093          DETROIT_PISTONS            2289       2  CHICAGO_BULLS
# 9383            ORLANDO_MAGIC            2002       1  CHICAGO_BULLS
# 9996            ATLANTA_HAWKS            1798       3  CHICAGO_BULLS
# 10424         MILWAUKEE_BUCKS            1552       0  CHICAGO_BULLS
# 10809               UTAH_JAZZ            2044       2  CHICAGO_BULLS
# 11125          BOSTON_CELTICS            2389       1  CHICAGO_BULLS
# 11417        DALLAS_MAVERICKS            2090       1  CHICAGO_BULLS
# 11861    NEW_ORLEANS_PELICANS            1520       0  CHICAGO_BULLS
# 12061          INDIANA_PACERS            2233       1  CHICAGO_BULLS
#
#        rebounds  points
# 181           0       2
# 349           3       9
# 602           2       8
# 994           3       2
# 1224          2       8
# 1550          0       7
# 1801          4       9
# 2066          4       7
# 2157          7      27
# 2731          3      10
# 3196          2       5
# 3428          4      10
# 3775          8       5
# 4139          1       5
# 4287          4      15
# 4638          2       6
# 4764          3      10
# 5169          5      11
# 5341          7      19
# 5667          3      12
# 6206          2      14
# 6482          6      13
# 6871          2       6
# 7177          3       6
# 7266          3      10
# 7642          2       7
# 7968          3       7
# 8094          3       7
# 8338          6      11
# 8600          7      17
# 9093          8      16
# 9383          6      20
# 9996          8      11
# 10424         2      10
# 10809         0       8
# 11125         6      12
# 11417         5      11
# 11861         4       6
# 12061         3      13
